# %%
import plotly.io as pio
pio.renderers.default = 'notebook'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import glob

# %%
glob.glob(r'E:\zeyad\data analyst projects\Stock analysis\S&P_resources\individual_stocks_5yr\*csv')
# Out:
# ['E:\\zeyad\\data analyst projects\\Stock analysis\\S&P_resources\\individual_stocks_5yr\\AAL_data.csv',
#  'E:\\zeyad\\data analyst projects\\Stock analysis\\S&P_resources\\individual_stocks_5yr\\AAPL_data.csv',
#  'E:\\zeyad\\data analyst projects\\Stock analysis\\S&P_resources\\individual_stocks_5yr\\AAP_data.csv',
#  'E:\\zeyad\\data analyst projects\\Stock analysis\\S&P_resources\\individual_stocks_5yr\\ABBV_data.csv',
#  'E:\\zeyad\\data analyst projects\\Stock analysis\\S&P_resources\\individual_stocks_5yr\\ABC_data.csv',
#  'E:\\zeyad\\data analyst projects\\Stock analysis\\S&P_resources\\individual_stocks_5yr\\ABT_data.csv',
#  'E:\\zeyad\\data analyst projects\\Stock analysis\\S&P_resources\\individual_stocks_5yr\\ACN_data.csv',
#  'E:\\zeyad\\data analyst projects\\Stock analysis\\S&P_resources\\individual_stocks_5yr\\ADBE_data.csv',
#  'E:\\zeyad\\data analyst projects\\Stock analysis\\S&P_resources\\individual_stocks_5yr\\ADI_data.csv',
# ...

# %%
company_list=[
    r'E:\\zeyad\\data analyst projects\\Stock analysis\\S&P_resources\\individual_stocks_5yr\\AAPL_data.csv',
    r'E:\\zeyad\\data analyst projects\\Stock analysis\\S&P_resources\\individual_stocks_5yr\\AMZN_data.csv',
    r'E:\\zeyad\\data analyst projects\\Stock analysis\\S&P_resources\\individual_stocks_5yr\\GOOG_data.csv',
    r'E:\\zeyad\\data analyst projects\\Stock analysis\\S&P_resources\\individual_stocks_5yr\\MSFT_data.csv',
]

# %%
full_data=pd.DataFrame()

for file in company_list:
    current_file=pd.read_csv(file)
    full_data=current_file.append(full_data)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_17828\1001196893.py:5: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_17828\1001196893.py:5: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_17828\1001196893.py:5: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_17828\1001196893.py:5: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
full_data.head()
# Out:
#          date   open   high    low  close    volume  Name
# 0  2013-02-08  27.35  27.71  27.31  27.55  33318306  MSFT
# 1  2013-02-11  27.65  27.92  27.50  27.86  32247549  MSFT
# 2  2013-02-12  27.88  28.00  27.75  27.88  35990829  MSFT
# 3  2013-02-13  27.93  28.11  27.88  28.03  41715530  MSFT
# 4  2013-02-14  27.92  28.06  27.87  28.04  32663174  MSFT

# %%
full_data.shape
# Out:
# (4752, 7)

# %%
full_data.isna().sum()
# Out:
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# Name      0
# dtype: int64

# %%
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4752 entries, 0 to 1258
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    4752 non-null   object
#  1   open    4752 non-null   float64
#  2   high    4752 non-null   float64
#  3   low     4752 non-null   float64
#  4   close   4752 non-null   float64
#  5   volume  4752 non-null   int64
#  6   Name    4752 non-null   object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 297.0+ KB

# %%
full_data.describe()
# Out:
#               open         high          low        close        volume
# count  4752.000000  4752.000000  4752.000000  4752.000000  4.752000e+03
# mean    344.075960   346.906095   340.992481   344.100091  2.465232e+07
# std     329.660871   332.181676   326.876297   329.705792  2.956724e+07
# min      27.350000    27.600000    27.230000    27.370000  7.932000e+03
# 25%      67.031000    67.668125    66.528900    66.836000  2.562696e+06
# 50%     153.740000   154.260000   152.685000   153.470000  1.796529e+07
# 75%     587.527500   592.625000   582.050000   587.092500  3.601633e+07
# max    1477.390000  1498.000000  1450.040000  1450.890000  2.668336e+08

# %%
full_data.duplicated().sum()
# Out:
# 0

# %%
full_data.head()
# Out:
#          date   open   high    low  close    volume  Name
# 0  2013-02-08  27.35  27.71  27.31  27.55  33318306  MSFT
# 1  2013-02-11  27.65  27.92  27.50  27.86  32247549  MSFT
# 2  2013-02-12  27.88  28.00  27.75  27.88  35990829  MSFT
# 3  2013-02-13  27.93  28.11  27.88  28.03  41715530  MSFT
# 4  2013-02-14  27.92  28.06  27.87  28.04  32663174  MSFT

# %%
full_data.dtypes
# Out:
# date       object
# open      float64
# high      float64
# low       float64
# close     float64
# volume      int64
# Name       object
# dtype: object

# %%
full_data['date']=pd.to_datetime(full_data['date'])

# %%
full_data.dtypes
# Out:
# date      datetime64[ns]
# open             float64
# high             float64
# low              float64
# close            float64
# volume             int64
# Name              object
# dtype: object

# %%
msft=full_data[full_data['Name']=='MSFT']

# %%
msft.head()
# Out:
#         date   open   high    low  close    volume  Name
# 0 2013-02-08  27.35  27.71  27.31  27.55  33318306  MSFT
# 1 2013-02-11  27.65  27.92  27.50  27.86  32247549  MSFT
# 2 2013-02-12  27.88  28.00  27.75  27.88  35990829  MSFT
# 3 2013-02-13  27.93  28.11  27.88  28.03  41715530  MSFT
# 4 2013-02-14  27.92  28.06  27.87  28.04  32663174  MSFT

# %%
import plotly.express as px

# %%
sns.lineplot(x='date',y='close',data=msft)
plt.title('msft')
# Out:
# Text(0.5, 1.0, 'msft')

# %%
full_data['Name'].unique()
# Out:
# array(['MSFT', 'GOOG', 'AMZN', 'AAPL'], dtype=object)

# %%
google=full_data[full_data['Name']=='GOOG']

# %%
px.line(google,x='date',y='close',title='google')
# Out:
# <div>                            <div id="9e225da7-f389-401f-bbaa-44328c8cc5ea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e225da7-f389-401f-bbaa-44328c8cc5ea")) {                    Plotly.newPlot(                        "9e225da7-f389-401f-bbaa-44328c8cc5ea",                        [{"hovertemplate":"date=%{x}<br>close=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2014-03-27T00:00:00","2014-03-28T00:00:00","2014-03-31T00:00:00","2014-04-01T00:00:00","2014-04-02T00:00:00","2014-04-03T00:00:00","2014-04-04T00:00:00","2014-04-07T00:00:00","2014-04-08T00:00:00","2014-04-09T00:00:00","2014-04-10T00:00:00","2014-04-11T
# ...

# %%
apple=full_data[full_data['Name']=='AAPL']

# %%
px.line(apple,x='date',y='close',title='apple')
# Out:
# <div>                            <div id="892abe77-a1c3-472f-b294-f1216bd3e6ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("892abe77-a1c3-472f-b294-f1216bd3e6ef")) {                    Plotly.newPlot(                        "892abe77-a1c3-472f-b294-f1216bd3e6ef",                        [{"hovertemplate":"date=%{x}<br>close=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2013-02-08T00:00:00","2013-02-11T00:00:00","2013-02-12T00:00:00","2013-02-13T00:00:00","2013-02-14T00:00:00","2013-02-15T00:00:00","2013-02-19T00:00:00","2013-02-20T00:00:00","2013-02-21T00:00:00","2013-02-22T00:00:00","2013-02-25T00:00:00","2013-02-26T00:00:00","2013-02
# ...

# %%
amazon=full_data[full_data['Name']=='AMZN']

# %%
px.line(amazon,x='date',y='close',title='amazon')
# Out:
# <div>                            <div id="9a098ad0-67d4-48a7-ad79-f029c6bd6d67" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a098ad0-67d4-48a7-ad79-f029c6bd6d67")) {                    Plotly.newPlot(                        "9a098ad0-67d4-48a7-ad79-f029c6bd6d67",                        [{"hovertemplate":"date=%{x}<br>close=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2013-02-08T00:00:00","2013-02-11T00:00:00","2013-02-12T00:00:00","2013-02-13T00:00:00","2013-02-14T00:00:00","2013-02-15T00:00:00","2013-02-19T00:00:00","2013-02-20T00:00:00","2013-02-21T00:00:00","2013-02-22T00:00:00","2013-02-25T00:00:00","2013-02-26T00:00:00","2013-02
# ...

# %%
msft['Daily_return%']=msft['close'].pct_change()*100
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_17828\4192643022.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
px.line(msft,x='date',y='Daily_return%',title='msft Daily_return')
# Out:
# <div>                            <div id="84339c6d-bb0b-4e57-a83b-cc2f9d4f1c38" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("84339c6d-bb0b-4e57-a83b-cc2f9d4f1c38")) {                    Plotly.newPlot(                        "84339c6d-bb0b-4e57-a83b-cc2f9d4f1c38",                        [{"hovertemplate":"date=%{x}<br>Daily_return%=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2013-02-08T00:00:00","2013-02-11T00:00:00","2013-02-12T00:00:00","2013-02-13T00:00:00","2013-02-14T00:00:00","2013-02-15T00:00:00","2013-02-19T00:00:00","2013-02-20T00:00:00","2013-02-21T00:00:00","2013-02-22T00:00:00","2013-02-25T00:00:00","2013-02-26T00:00:00",
# ...

# %%
apple['Daily_return%']=apple['close'].pct_change()*100
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_17828\1740791513.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
px.line(apple,x='date',y='Daily_return%',title='apple Daily return')
# Out:
# <div>                            <div id="783eb48f-5c79-4451-b3ba-61f657007a4f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("783eb48f-5c79-4451-b3ba-61f657007a4f")) {                    Plotly.newPlot(                        "783eb48f-5c79-4451-b3ba-61f657007a4f",                        [{"hovertemplate":"date=%{x}<br>Daily_return%=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2013-02-08T00:00:00","2013-02-11T00:00:00","2013-02-12T00:00:00","2013-02-13T00:00:00","2013-02-14T00:00:00","2013-02-15T00:00:00","2013-02-19T00:00:00","2013-02-20T00:00:00","2013-02-21T00:00:00","2013-02-22T00:00:00","2013-02-25T00:00:00","2013-02-26T00:00:00",
# ...

# %%
new_data=full_data.copy()

# %%
m_a=[10,30,60]
for ma in m_a:
    new_data['close'+str(ma)]=new_data['close'].rolling(window=ma).mean()

# %%
new_data.head()
# Out:
#         date   open   high    low  close    volume  Name  close10  close30  \
# 0 2013-02-08  27.35  27.71  27.31  27.55  33318306  MSFT      NaN      NaN
# 1 2013-02-11  27.65  27.92  27.50  27.86  32247549  MSFT      NaN      NaN
# 2 2013-02-12  27.88  28.00  27.75  27.88  35990829  MSFT      NaN      NaN
# 3 2013-02-13  27.93  28.11  27.88  28.03  41715530  MSFT      NaN      NaN
# 4 2013-02-14  27.92  28.06  27.87  28.04  32663174  MSFT      NaN      NaN
#
#    close60
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
new_data.tail()
# Out:
#            date     open    high       low   close    volume  Name  close10  \
# 1254 2018-02-01  167.165  168.62  166.7600  167.78  47230787  AAPL  171.948
# 1255 2018-02-02  166.000  166.80  160.1000  160.50  86593825  AAPL  170.152
# 1256 2018-02-05  159.100  163.88  156.0000  156.49  72738522  AAPL  168.101
# 1257 2018-02-06  154.830  163.72  154.0000  163.03  68243838  AAPL  166.700
# 1258 2018-02-07  163.085  163.40  159.0685  159.54  51608580  AAPL  165.232
#
#          close30     close60
# 1254  173.409333  172.879167
# 1255  172.941333  172.650000
# 1256  172.346000  172.344667
# 1257  171.946667  172.124500
# 1258  171.431000  171.852167

# %%
msft_close=new_data[new_data['Name']=='MSFT']

# %%
px.line(msft_close,x='date',y=['close10','close30','close60'])
# Out:
# <div>                            <div id="3e95f243-d6a7-4a53-96af-0d52c27ce44a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3e95f243-d6a7-4a53-96af-0d52c27ce44a")) {                    Plotly.newPlot(                        "3e95f243-d6a7-4a53-96af-0d52c27ce44a",                        [{"hovertemplate":"variable=close10<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"close10","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"close10","showlegend":true,"x":["2013-02-08T00:00:00","2013-02-11T00:00:00","2013-02-12T00:00:00","2013-02-13T00:00:00","2013-02-14T00:00:00","2013-02-15T00:00:00","2013-02-19T00:00:00","2013-02-20T00:00:00","2013-02-21T00:00:00","2013-02-22T00:00:00","2013-02-25T00:00:0
# ...

# %%
google_close=new_data[new_data['Name']=='GOOG']

# %%
px.line(google_close,x='date',y=['close10','close30','close60'])
# Out:
# <div>                            <div id="d120e810-69e6-41e3-b1e1-4dd2594b8428" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d120e810-69e6-41e3-b1e1-4dd2594b8428")) {                    Plotly.newPlot(                        "d120e810-69e6-41e3-b1e1-4dd2594b8428",                        [{"hovertemplate":"variable=close10<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"close10","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"close10","showlegend":true,"x":["2014-03-27T00:00:00","2014-03-28T00:00:00","2014-03-31T00:00:00","2014-04-01T00:00:00","2014-04-02T00:00:00","2014-04-03T00:00:00","2014-04-04T00:00:00","2014-04-07T00:00:00","2014-04-08T00:00:00","2014-04-09T00:00:00","2014-04-10T00:00:0
# ...

# %%
amazon_close=new_data[new_data['Name']=='AMZN']

# %%
px.line(amazon_close,x='date',y=['close10','close30','close60'])
# Out:
# <div>                            <div id="feb5f622-ae46-445d-9038-00a611a0c5c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("feb5f622-ae46-445d-9038-00a611a0c5c7")) {                    Plotly.newPlot(                        "feb5f622-ae46-445d-9038-00a611a0c5c7",                        [{"hovertemplate":"variable=close10<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"close10","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"close10","showlegend":true,"x":["2013-02-08T00:00:00","2013-02-11T00:00:00","2013-02-12T00:00:00","2013-02-13T00:00:00","2013-02-14T00:00:00","2013-02-15T00:00:00","2013-02-19T00:00:00","2013-02-20T00:00:00","2013-02-21T00:00:00","2013-02-22T00:00:00","2013-02-25T00:00:0
# ...

# %%
apple_close=new_data[new_data['Name']=='AAPL']

# %%
px.line(apple_close,x='date',y=['close10','close30','close60'])
# Out:
# <div>                            <div id="c2e9d669-b8d7-475b-8ea4-c115d238f39a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2e9d669-b8d7-475b-8ea4-c115d238f39a")) {                    Plotly.newPlot(                        "c2e9d669-b8d7-475b-8ea4-c115d238f39a",                        [{"hovertemplate":"variable=close10<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"close10","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"close10","showlegend":true,"x":["2013-02-08T00:00:00","2013-02-11T00:00:00","2013-02-12T00:00:00","2013-02-13T00:00:00","2013-02-14T00:00:00","2013-02-15T00:00:00","2013-02-19T00:00:00","2013-02-20T00:00:00","2013-02-21T00:00:00","2013-02-22T00:00:00","2013-02-25T00:00:0
# ...

# %%
apple.head()
# Out:
#         date     open     high      low    close     volume  Name  \
# 0 2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1 2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2 2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3 2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4 2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL
#
#    Daily_return%
# 0            NaN
# 1       1.042235
# 2      -2.506658
# 3      -0.190297
# 4      -0.089934

# %%
apple.set_index('date',inplace=True)

# %%
apple.head()
# Out:
#                open     high      low    close     volume  Name  Daily_return%
# date
# 2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL            NaN
# 2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL       1.042235
# 2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL      -2.506658
# 2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL      -0.190297
# 2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL      -0.089934

# %%
apple_avg_year_stock=apple['close'].resample('Y').mean()

# %%
px.line(apple_avg_year_stock,title='apple avg_year_stockprice')
# Out:
# <div>                            <div id="149a209e-df4b-420d-91d2-0470335a54a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("149a209e-df4b-420d-91d2-0470335a54a4")) {                    Plotly.newPlot(                        "149a209e-df4b-420d-91d2-0470335a54a4",                        [{"hovertemplate":"variable=close<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"close","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"close","orientation":"v","showlegend":true,"x":["2013-12-31T00:00:00","2014-12-31T00:00:00","2015-12-31T00:00:00","2016-12-31T00:00:00","2017-12-31T00:00:00","2018-12-31T00:00:00"],"xaxis":"x","y":[67.23783938053097,92.26453055555555,120.03986111111111,104.60400793650793,150
# ...

# %%
msft.set_index('date',inplace=True)

# %%
msft_avg_year_stock=msft['close'].resample('Y').mean()

# %%
px.line(msft_avg_year_stock,title='msft avg_year_stockprice')
# Out:
# <div>                            <div id="be6858e3-cf2f-4240-9df9-c47d0b89b118" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be6858e3-cf2f-4240-9df9-c47d0b89b118")) {                    Plotly.newPlot(                        "be6858e3-cf2f-4240-9df9-c47d0b89b118",                        [{"hovertemplate":"variable=close<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"close","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"close","orientation":"v","showlegend":true,"x":["2013-12-31T00:00:00","2014-12-31T00:00:00","2015-12-31T00:00:00","2016-12-31T00:00:00","2017-12-31T00:00:00","2018-12-31T00:00:00"],"xaxis":"x","y":[33.09026991150442,42.45334325396826,46.71380952380952,55.25930555555555,71.98
# ...

# %%
apple.reset_index(inplace=True)

# %%
msft.reset_index(inplace=True)

# %%
close_price=pd.DataFrame()

# %%
close_price['apple_close']=apple['close']
close_price['msft_close']=msft['close']
close_price['amazon_close']=amazon['close']
close_price['google_close']=google['close']

# %%
close_price.head()
# Out:
#    apple_close  msft_close  amazon_close  google_close
# 0      67.8542       27.55        261.95        558.46
# 1      68.5614       27.86        257.21        559.99
# 2      66.8428       27.88        258.70        556.97
# 3      66.7156       28.03        269.47        567.16
# 4      66.6556       28.04        269.24        567.00

# %%
sns.pairplot(close_price)

# %%
close_price.corr()
# Out:
#               apple_close  msft_close  amazon_close  google_close
# apple_close      1.000000    0.899689      0.819078      0.640522
# msft_close       0.899689    1.000000      0.955977      0.907011
# amazon_close     0.819078    0.955977      1.000000      0.888456
# google_close     0.640522    0.907011      0.888456      1.000000

# %%
sns.heatmap(close_price.corr(),annot=True)
# Out:
# <Axes: >

# %%
close_price_change=pd.DataFrame()

# %%
amazon['Daily_return%']=amazon['close'].pct_change()*100
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_17828\1339788314.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
google['Daily_return%']=google['close'].pct_change()*100
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_17828\3402116955.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
close_price_change['apple_daily_return']=apple['Daily_return%']
close_price_change['amazon_daily_ruturn']=amazon['Daily_return%']
close_price_change['google_daily_return']=google['Daily_return%']
close_price_change['msft_daily_return']=msft['Daily_return%']

# %%
close_price_change.head()
# Out:
#    apple_daily_return  amazon_daily_ruturn  google_daily_return  \
# 0                 NaN                  NaN                  NaN
# 1            1.042235            -1.809506             0.273968
# 2           -2.506658             0.579293            -0.539295
# 3           -0.190297             4.163123             1.829542
# 4           -0.089934            -0.085353            -0.028211
#
#    msft_daily_return
# 0                NaN
# 1           1.125227
# 2           0.071788
# 3           0.538020
# 4           0.035676

# %%
sns.pairplot(close_price_change)

# %%
sns.heatmap(close_price_change.corr(),annot=True)
# Out:
# <Axes: >
